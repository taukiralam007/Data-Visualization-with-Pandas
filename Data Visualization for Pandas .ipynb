# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df = pd.DataFrame(np.random.randn(10,4),index=pd.date_range('1/1/2000',periods=10),columns = list('1234'))

# %%
df.head()
# Out:
#                    1         2         3         4
# 2000-01-01  0.023161 -0.048392 -3.362203  0.876927
# 2000-01-02  0.445020 -1.332985  0.091914  0.555837
# 2000-01-03 -0.157874  1.142949 -0.533918 -0.766927
# 2000-01-04 -0.649379  0.972522 -0.233764  0.347348
# 2000-01-05  0.575990 -1.536650  0.498659 -0.984782

# %%
output = df['A'].plot()

# %%
import matplotlib.pyplot as plt 
plt.savefig('output.jpg') # save as jpg
plt.savefig('output.png') # save as png

# %%
import numpy as np
from matplotlib import pyplot as plt
def sinplot(flip=1):
    x = np.linspace(0,14,100)
    for i in range(1,5):
        plt.plot(x,np.sin(x+i*.5)*(7-i)*flip)
import seaborn as sb
sb.set_style("whitegrid")
sinplot()
plt.show()

# %%
df = pd.DataFrame(np.random.rand(10,4),columns =['a','b','c','d'])

# %%
df
# Out:
#           a         b         c         d
# 0  0.386775  0.967098  0.975835  0.288238
# 1  0.100264  0.677669  0.041874  0.685621
# 2  0.141575  0.135887  0.418231  0.863501
# 3  0.586949  0.820143  0.760083  0.917160
# 4  0.682845  0.673211  0.862857  0.788836
# 5  0.048276  0.773648  0.317679  0.329404
# 6  0.724665  0.535770  0.890255  0.030714
# 7  0.753673  0.084459  0.151826  0.961714
# 8  0.660829  0.779970  0.912442  0.397989
# 9  0.957469  0.702425  0.730672  0.095043

# %%
df= pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])

# %%
df
# Out:
#           a         b         c         d
# 0  0.688581  0.721319  0.588689  0.994683
# 1  0.921883  0.341420  0.860555  0.348236
# 2  0.969266  0.806679  0.914989  0.002426
# 3  0.198465  0.902231  0.720400  0.455520
# 4  0.799578  0.379797  0.968694  0.158020
# 5  0.287921  0.131623  0.993756  0.238071
# 6  0.263768  0.125589  0.735319  0.550771
# 7  0.497576  0.570681  0.377839  0.328267
# 8  0.515435  0.259332  0.233748  0.462410
# 9  0.191601  0.740645  0.806222  0.187284

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot.barh(stacked = True)
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame({'a':np.random.randn(1000)+1, 'b':np.random.randn(1000), 'c':np.random.randn(1000)-1}, columns=['a','b','c','d'])

# %%
df
# Out:
#             a         b         c    d
# 0    1.059466 -0.369755 -2.213824  NaN
# 1    0.701650  0.530993 -1.934315  NaN
# 2    1.844947 -1.848652 -1.468199  NaN
# 3    0.804402  0.301004 -2.381407  NaN
# 4    0.254423  0.663649 -1.069826  NaN
# ..        ...       ...       ...  ...
# 995  1.928822  1.021080 -1.791520  NaN
# 996  0.146544 -0.951064  1.049731  NaN
# 997  0.503288  0.512161  0.474635  NaN
# 998  0.789035  0.571737 -1.972834  NaN
# 999  2.560286  0.215533 -0.689653  NaN
#
# [1000 rows x 4 columns]

# %%
df['a']
# Out:
# 0      1.059466
# 1      0.701650
# 2      1.844947
# 3      0.804402
# 4      0.254423
#          ...
# 995    1.928822
# 996    0.146544
# 997    0.503288
# 998    0.789035
# 999    2.560286
# Name: a, Length: 1000, dtype: float64

# %%
df['a'].plot.hist(bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame({'a': np.random.randn(1000)+1 , 'b':np.random.randn(1000), 'c': np.random.randn(1000)-1}, columns = ['a','b','c','d'])

# %%
df
# Out:
#             a         b         c    d
# 0   -0.549341 -0.197289 -2.061876  NaN
# 1    0.114231 -0.187687 -1.018032  NaN
# 2    0.752049 -0.293383 -1.148179  NaN
# 3    0.309827 -0.489956 -2.318786  NaN
# 4    0.498654  0.166465 -1.003660  NaN
# ..        ...       ...       ...  ...
# 995  2.184843  0.411997 -0.528969  NaN
# 996  1.002797  0.597017 -2.705269  NaN
# 997  1.590919  0.963193 -0.889936  NaN
# 998  0.679509  0.742569 -1.328333  NaN
# 999  1.736069  0.235121 -1.849970  NaN
#
# [1000 rows x 4 columns]

# %%
df['a'].plot.hist(bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['b'].plot.hist(bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['c'].plot.hist(bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['d'].plot.hist(bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
import pandas as pd
import numpy as np
df=pd.DataFrame({'a':np.random.randn(1000)+1 , 'b':np.random.randn(1000), 'c':np.random.randn(1000)-1},columns=['a','b','c','d'])

# %%
df.plot.hist(bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df = pd.DataFrame(np.random.rand(10,5), columns = ['A','B','C','D','E'])

# %%
df
# Out:
#           A         B         C         D         E
# 0  0.836390  0.107431  0.405614  0.418743  0.537083
# 1  0.905653  0.388655  0.211097  0.452252  0.780182
# 2  0.515975  0.684295  0.093957  0.844776  0.097772
# 3  0.610329  0.479758  0.519042  0.286178  0.519734
# 4  0.200654  0.856972  0.274906  0.701700  0.180027
# 5  0.472863  0.294279  0.137079  0.753655  0.299598
# 6  0.638339  0.747692  0.933223  0.669740  0.102633
# 7  0.898025  0.777784  0.684700  0.549762  0.917572
# 8  0.193989  0.418519  0.684108  0.587731  0.675185
# 9  0.317918  0.272524  0.588821  0.886163  0.940128

# %%
df['A'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['B'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['C'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['D'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df = pd.DataFrame(np.random.rand(10,4),columns =['a','b','c','d'])

# %%
df
# Out:
#           a         b         c         d
# 0  0.893174  0.836311  0.956425  0.942813
# 1  0.510264  0.764162  0.630860  0.387468
# 2  0.596693  0.307940  0.298431  0.511500
# 3  0.602830  0.469789  0.297397  0.316558
# 4  0.333629  0.334695  0.495505  0.162146
# 5  0.372332  0.824693  0.766992  0.370519
# 6  0.656779  0.763215  0.520576  0.654165
# 7  0.987459  0.901028  0.296250  0.657266
# 8  0.167455  0.274848  0.925129  0.705900
# 9  0.043003  0.340351  0.302063  0.701252

# %%
df = pd.DataFrame(np.random.rand(10,4), columns=['A','B','C','D'])

# %%
df
# Out:
#           A         B         C         D
# 0  0.853740  0.093374  0.057224  0.951892
# 1  0.006758  0.783144  0.697855  0.011332
# 2  0.506328  0.542732  0.401345  0.040240
# 3  0.003557  0.158583  0.917699  0.882539
# 4  0.834810  0.362678  0.012226  0.192034
# 5  0.640148  0.523453  0.842984  0.227618
# 6  0.995116  0.153361  0.396316  0.284234
# 7  0.193812  0.547599  0.771898  0.084613
# 8  0.982014  0.988209  0.789303  0.411563
# 9  0.761254  0.473798  0.075590  0.432136

# %%
df['A'].plot.area()
# Out:
# <AxesSubplot:>

# %%
df['B'].plot.area()
# Out:
# <AxesSubplot:>

# %%
df['C'].plot.area()
# Out:
# <AxesSubplot:>

# %%
df['D'].plot.area()
# Out:
# <AxesSubplot:>

# %%
df =pd.DataFrame(np.random.rand(50,4),columns =['a','b','c','d'])

# %%
df
# Out:
#            a         b         c         d
# 0   0.510928  0.001779  0.606878  0.441562
# 1   0.600758  0.739633  0.513683  0.307860
# 2   0.000358  0.588986  0.064127  0.493127
# 3   0.839135  0.966195  0.098625  0.885560
# 4   0.544585  0.678004  0.193749  0.349430
# 5   0.359945  0.617009  0.816429  0.582328
# 6   0.835067  0.726434  0.579687  0.733254
# 7   0.954433  0.924781  0.775075  0.657728
# 8   0.922128  0.973436  0.915710  0.539337
# 9   0.397958  0.143872  0.569277  0.842194
# 10  0.233378  0.152714  0.792540  0.317057
# 11  0.513691  0.074409  0.433321  0.880771
# 12  0.543774  0.580576  0.505602  0.261862
# 13  0.456985  0.881591  0.522299  0.257087
# 14  0.068435  0.472117  0.179429  0.946713
# 15  0.175920  0.638403  0.051931  0.399825
# 16  0.816877  0.423015  0.254893  0.817068
# 17  0.053953  0.320441  0.153600  0.633952
# 18  0.875692  0.999415  0.888510  0.604084
# 19  0.468102  0.725706  0.856467  0.924466
# 20  0.416232  0.722648  0.351899  0.890295
# 21  0.704895  0.259115  0.406462  0.055703
# 22  0.702474  0.817133  0.156520  0.665691
# 23  0.307086  0.368277  0.642185  0.896258
# 24  0.602321  0.023021  0.297714  0.812857
# 25  0.436900  0.909992  0.170284  0.981114
# 26  0.044123  0.226052  0.858121  0.058008
# 27  0.206184  0.182112  0.197148  0.037378
# 28  0.422462  0.675404  0.815976  0.423035
# 29  0.247218  0.220233  0.505120  0.795571
# 30  0.363499  0.171830  0.586186  0.791082
# 31  0.921277  0.031945  0.134779  0.337116
# 32  0.230347  0.561104  0.954196  0.395000
# 33  0.325559  0.200520  0.980788  0.490038
# 34  0.895657  0.939140  0.816683  0.499758
# 35  0.271941  0.981195  0.952919  0.955126
# 36  0.374238  0.407810  0.057651  0.144865
# 37  0.191195  0.996476  0.292285  0.948881
# 38  0.513818  0.186242  0.189780  0.776017
# 39  0.285652  0.658693  0.933824  0.666965
# 40  0.621841  0.131958  0.916318  0.764237
# 41  0.841108  0.332238  0.590892  0.960774
# 42  0.567261  0.259551  0.565534  0.014244
# 43  0.052081  0.221295  0.520612  0.815096
# 44  0.707371  0.687561  0.750605  0.949379
# 45  0.323821  0.509418  0.202919  0.155316
# 46  0.085049  0.817831  0.927076  0.192590
# 47  0.896370  0.765708  0.767856  0.307684
# 48  0.383143  0.038888  0.734510  0.358224
# 49  0.409769  0.579753  0.357385  0.323402

# %%
df.head()
# Out:
#           a         b         c         d
# 0  0.510928  0.001779  0.606878  0.441562
# 1  0.600758  0.739633  0.513683  0.307860
# 2  0.000358  0.588986  0.064127  0.493127
# 3  0.839135  0.966195  0.098625  0.885560
# 4  0.544585  0.678004  0.193749  0.349430

# %%
df.plot.scatter(x='a',y='b')
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df = pd.DataFrame(3*np.random.rand(4),index=['a','b','c','d'],columns =['X')
# Out:
#   File "<ipython-input-106-9cd0bca086df>", line 1
#     df = pd.DataFrame(3*np.random.rand(4),index=['a','b','c','d'],columns =['X')
#                                                                                ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %%
df
# Out:
#           X
# a  0.240836
# b  2.420939
# c  1.172706
# d  0.332178

# %%
df.plot.pie(subplots=True)
# Out:
# array([<AxesSubplot:ylabel='X'>], dtype=object)

# %% [markdown]
# ## Matplotlib plotting

# %%
import matplotlib.pyplot as plt 
import numpy as np

# %%
np.random.rand(4)
# Out:
# array([0.88021951, 0.27604011, 0.3248049 , 0.36965287])

# %%
df = pd.DataFrame(np.random.rand(50,4),columns=['a','b','c','d'])

# %%
dataframe = pd.DataFrame(np.random.rand(50,4),columns=['a','b','c','d'])

# %%
fig = plt.hist(dataframe)

# %%
plt.savefig('hist1.png')

# %%
plt.style.use()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-131-39f510d45dca> in <module>
# ----> 1 plt.style.use()
#
# TypeError: use() missing 1 required positional argument: 'style'

# %%
# make data
x = np.linspace(0,10,100)
y = 4+2*np.sin(2*x)

# %%
x
# Out:
# array([ 0.        ,  0.1010101 ,  0.2020202 ,  0.3030303 ,  0.4040404 ,
#         0.50505051,  0.60606061,  0.70707071,  0.80808081,  0.90909091,
#         1.01010101,  1.11111111,  1.21212121,  1.31313131,  1.41414141,
#         1.51515152,  1.61616162,  1.71717172,  1.81818182,  1.91919192,
#         2.02020202,  2.12121212,  2.22222222,  2.32323232,  2.42424242,
#         2.52525253,  2.62626263,  2.72727273,  2.82828283,  2.92929293,
#         3.03030303,  3.13131313,  3.23232323,  3.33333333,  3.43434343,
#         3.53535354,  3.63636364,  3.73737374,  3.83838384,  3.93939394,
#         4.04040404,  4.14141414,  4.24242424,  4.34343434,  4.44444444,
#         4.54545455,  4.64646465,  4.74747475,  4.84848485,  4.94949495,
#         5.05050505,  5.15151515,  5.25252525,  5.35353535,  5.45454545,
#         5.55555556,  5.65656566,  5.75757576,  5.85858586,  5.95959596,
#         6.06060606,  6.16161616,  6.26262626,  6.36363636,  6.46464646,
#         6.56565657,  6.66666667,  6.76767677,  6.86868687,  6.96969697,
#         7.07070707,  7.17171717,  7.27272727,  7.37373737,  7.47474747,
#         7.57575758,  7.67676768,  7.77777778,  7.87878788,  7.97979798,
#         8.08080808,  8.18181818,  8.28282828,  8.38383838,  8.48484848,
#         8.58585859,  8.68686869,  8.78787879,  8.88888889,  8.98989899,
#         9.09090909,  9.19191919,  9.29292929,  9.39393939,  9.49494949,
#         9.5959596 ,  9.6969697 ,  9.7979798 ,  9.8989899 , 10.        ])

# %%
y
# Out:
# array([4.        , 4.40129771, 4.78627322, 5.13926821, 5.44592512,
#        5.69377113, 5.87272545, 5.97550938, 5.99794234, 5.9391119 ,
#        5.80141089, 5.59044011, 5.31478049, 4.98564409, 4.61641803,
#        4.22212008, 3.81878771, 3.42282588, 3.05033978, 2.71647972,
#        2.43482499, 2.21683149, 2.07136577, 2.00434444, 2.01849351,
#        2.11323748, 2.28472278, 2.52597448, 2.82718004, 3.17608834,
#        3.55850805, 3.95888481, 4.36093386, 4.74830246, 5.10523494,
#        5.4172136 , 5.67154914, 5.85789686, 5.96867732, 5.99938468,
#        5.94876998, 5.81889189, 5.61503301, 5.34548501, 5.02121136,
#        4.65540142, 4.26293398, 3.85977208, 3.46231375, 3.08672502,
#        2.74828243, 2.46075164, 2.23582754, 2.08265859, 2.00747471,
#        2.01333392, 2.09999787, 2.26394166, 2.4984971 , 2.79412399,
#        3.13879814, 3.51850042, 3.91778699, 4.32041746, 4.71001542,
#        5.07073453, 5.38790307, 5.64862067, 5.84228301, 5.96101317,
#        5.99998196, 5.95760439, 5.83560411, 5.63894329, 5.37562084,
#        5.056347  , 4.69410779, 4.30363675, 3.90081572, 3.50202887,
#        3.12349628, 2.7806142 , 2.48732886, 2.25556923, 2.09476179,
#        2.01144714, 2.009014  , 2.08756132, 2.24389431, 2.47165434,
#        2.76157762, 3.10187193, 3.47869629, 3.87672393, 4.27976564,
#        4.67142829, 5.03578156, 5.35800593, 5.62499538, 5.8258905 ])

# %%
plt.plot(x,y)

# %%
# plot 
fig, ax = plt.subplots()
ax.set(xlim =(0,8),xticks=np.arange(1,8),
      ylim =(0,8),yticks=np.arange(18))
plt.show()

# %%
# plt.style.use('_mpl-gallery')
#make data
x = np.linspace(0,10,100)
y = 4+2*np.sin(2*x)
# plot
fig, ax = plt.subplots(4)
print(ax)

ax.plot(x,y, linewidth=2.0)

ax.set(xlim=(0,8),xticks=np.arange(1,8),
       ylim=(0,8),yticks=np.arange(1,8))
plt.show()
# Out:
# [<AxesSubplot:> <AxesSubplot:> <AxesSubplot:> <AxesSubplot:>]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-143-056fe9346168> in <module>
#       7 print(ax)
#       8
# ----> 9 ax.plot(x,y, linewidth=2.0)
#      10
#      11 ax.set(xlim=(0,8),xticks=np.arange(1,8),
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %%
fig = plt.figure('[10,10]')
ax=fig.add_axes([0,0,1,1])
lang = ['python','java','c','c++']
stud = [50,40,30,20]
ax.bar(lang,stud)
plt.show()

# %%
fig = plt.figure('[10,10]')
ax =fig.add_axes([0,0,1,1])
langs = ['c','c++','java','python','PHP']
students = [23,17,35,29,12]
ax.bar(langs,students)
plt.show()

# %%
plt.bar(langs,students)
# Out:
# <BarContainer object of 5 artists>

# %%
from matplotlib import pyplot as plt
import numpy as np  
fix,ax = plt.subplots(1,1)
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27])
ax.hist(a,bins =[0,25,50,75,100])
ax.set_title(["histogram of result"])
ax.set_xlabel('marks')
ax.set_ylabel('no. of students')
plt.show()

# %%
from numpy.random import randn, randint , uniform, sample

# %%
df = pd.DataFrame(randn(1000),index = pd.date_range('2019-06-07',periods = 1000), columns =['values'])
ts = pd.Series(randn(1000), index=pd.date_range('2019-06-07',periods=1000))

# %%
df['values'] =df['values'].cumsum()
df.head()
# Out:
#                 values
# 2019-06-07    0.131229
# 2019-06-08    4.476616
# 2019-06-09   27.148017
# 2019-06-10  100.329568
# 2019-06-11  283.369137

# %%
ts = ts.cumsum()
ts.head()
# Out:
# 2019-06-07    1.034291
# 2019-06-08   -0.291703
# 2019-06-09   -0.947754
# 2019-06-10   -2.729862
# 2019-06-11   -2.051190
# Freq: D, dtype: float64

# %%
type(df),type(ts)
# Out:
# (pandas.core.frame.DataFrame, pandas.core.series.Series)

# %%
ts.plot(figsize=(5,5))
# Out:
# <AxesSubplot:>

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##  Seaborn plotting

# %%
import seaborn as sns

# %%
iris =sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.shape
# Out:
# (150, 5)

# %%
iris['species'].value_counts()
# Out:
# virginica     50
# versicolor    50
# setosa        50
# Name: species, dtype: int64

# %%
ax = iris.plot(figsize=(15,8),title = 'Iris Dataset')

# %%
iris['sepal_length'].min()
# Out:
# 4.3

# %%
iris['sepal_length'].max()
# Out:
# 7.9

# %%
iris['sepal_length'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df = iris.drop(['species'],axis=1)

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.iloc[0]
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
df.iloc[0].plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.iloc[0].plot.bar()
# Out:
# <AxesSubplot:>

# %%
titanic =sns.load_dataset('titanic')

# %%
titanic.columns
# Out:
# Index(['survived', 'pclass', 'sex', 'age', 'sibsp', 'parch', 'fare',
#        'embarked', 'class', 'who', 'adult_male', 'deck', 'embark_town',
#        'alive', 'alone'],
#       dtype='object')

# %%
titanic.shape
# Out:
# (891, 15)

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
titanic['fare'].plot(kind='hist',figsize=(10,10),title='Mygraph')
# Out:
# <AxesSubplot:title={'center':'Mygraph'}, ylabel='Frequency'>

# %%
df =pd.DataFrame(np.random.rand(10,4),columns=['a','b','c','d'])
df.head(10)
# Out:
#           a         b         c         d
# 0  0.118422  0.315385  0.682892  0.569384
# 1  0.495010  0.043326  0.598377  0.123265
# 2  0.624301  0.996597  0.234573  0.012650
# 3  0.454229  0.141468  0.891214  0.383151
# 4  0.222139  0.694473  0.090325  0.654710
# 5  0.328111  0.179636  0.787085  0.553887
# 6  0.321888  0.253157  0.545518  0.438930
# 7  0.733480  0.770749  0.671014  0.189330
# 8  0.290733  0.065067  0.947838  0.891352
# 9  0.518375  0.834652  0.928796  0.502169

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind ='bar')
# Out:
# <AxesSubplot:>

# %%
df.plot.barh()
# Out:
# <AxesSubplot:>

# %%
iris.plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind ='hist',stacked=False,bins =100)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
iris.plot(kind='hist',stacked=True, bins=50,orientation='horizontal')
# Out:
# <AxesSubplot:xlabel='Frequency'>

# %%
iris['sepal_width']
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
#       ...
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff()
# Out:
# 0      NaN
# 1     -0.5
# 2      0.2
# 3     -0.1
# 4      0.5
#       ...
# 145   -0.3
# 146   -0.5
# 147    0.5
# 148    0.4
# 149   -0.4
# Name: sepal_width, Length: 150, dtype: float64

# %%
iris['sepal_width'].diff().plot(kind='hist',stacked = True, bins =50)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df = iris.drop(['species'],axis=1)
df.diff().head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           NaN          NaN           NaN          NaN
# 1          -0.2         -0.5           0.0          0.0
# 2          -0.2          0.2          -0.1          0.0
# 3          -0.1         -0.1           0.2          0.0
# 4           0.4          0.5          -0.1          0.0

# %%
df.diff().hist(color='b',alpha=0.1,figsize=(10,10))
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
color={'boxes':'DarkGreen','Wiskers':'b'}

# %%
color
# Out:
# {'boxes': 'DarkGreen', 'Wiskers': 'b'}

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.plot.scatter(x='sepal_length',y = 'petal_length')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.scatter(x='sepal_length',y='petal_length',c='sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.plot.scatter(x='sepal_length', y = 'petal_length', label ='Length');
 # df.plot.scatter(x=sepal_width, y = 'petal_width', label='width',ax =ax, color='r')
# df.plot.scatter(x=sepal_width, y = 'petal_width', label='width',ax =ax, color='g')

# %%
df.plot.scatter(x ='sepal_length',y='petal_length',c='sepal_width',s=190)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
df.plot.hexbin(x='sepal_length',y = 'petal_length',gridsize=10,C='sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %%
d = df.iloc[0]

# %%
d
# Out:
# sepal_length    5.1
# sepal_width     3.5
# petal_length    1.4
# petal_width     0.2
# Name: 0, dtype: float64

# %%
d.plot.pie(figsize=(10,10))
# Out:
# <AxesSubplot:ylabel='0'>

# %%
d = df.head(3).T

# %%
d
# Out:
#                 0    1    2
# sepal_length  5.1  4.9  4.7
# sepal_width   3.5  3.0  3.2
# petal_length  1.4  1.4  1.3
# petal_width   0.2  0.2  0.2

# %%
d.plot.pie(subplots=True,figsize=(20,20))
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
d.plot.pie(subplots=True,figsize=(20,20),fontsize=26,autopct='%.2f')
# Out:
# array([<AxesSubplot:ylabel='0'>, <AxesSubplot:ylabel='1'>,
#        <AxesSubplot:ylabel='2'>], dtype=object)

# %%
[0.1]*4
# Out:
# [0.1, 0.1, 0.1, 0.1]

# %%
series = pd.Series([0.2]*5, index =['a','b','c','d','e'], name='Pie Plot')

# %%
series.plot.pie()
# Out:
# <AxesSubplot:ylabel='Pie Plot'>

# %%
from pandas.plotting import scatter_matrix

# %%
scatter_matrix(df,figsize=(8,8),diagonal='kde',color='g')
plt.show()

# %%
ts.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
from pandas.plotting import andrews_curves

# %%
andrews_curves(df,'sepal_width')
# Out:
# <AxesSubplot:>

# %%
ts.plot(style='r--',label = 'Series', legend = True)
# Out:
# <AxesSubplot:>

# %%
df.plot(legend=True, figsize=(10,5),logy=True)
# Out:
# <AxesSubplot:>

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width]
# Index: []

# %%
x =df.drop(['sepal_width','petal_width'],axis=1) 
x.head()
# Out:
#    sepal_length  petal_length
# 0           5.1           1.4
# 1           4.9           1.4
# 2           4.7           1.3
# 3           4.6           1.5
# 4           5.0           1.4

# %%
y=df.drop(['sepal_length','petal_length'],axis=1)
y.head()
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2

# %%
y = df.drop(['sepal_length','petal_length'],axis=1)
y.head()
# Out:
#    sepal_width  petal_width
# 0          3.5          0.2
# 1          3.0          0.2
# 2          3.2          0.2
# 3          3.1          0.2
# 4          3.6          0.2

# %%
ax = x.plot()
y.plot(figsize=(16,10),secondary_y=True,ax=ax)
# Out:
# <AxesSubplot:label='a55438aa-ea1d-459d-a30f-67ddd0b53e80'>

# %%
x.plot(figsize=(10,5),x_compat=True)
# Out:
# <AxesSubplot:>

# %%
df.plot(subplots=True)
# Out:
# array([<AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>],
#       dtype=object)

# %%
df.plot(subplots =True, sharex =False , layout=(2,3),figsize =(16,8))
plt.tight_layout()
